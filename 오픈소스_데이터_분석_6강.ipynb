# %% [markdown]
# <a href="https://colab.research.google.com/github/vicavica/Data-Analysis-with-Open-Source/blob/main/%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_6%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오픈소스 기반 데이터 분석 6강 - 데이터 전처리 1

# %% [markdown]
# ### 6-1 데이터 훑어보기

# %%
import pandas as pd
import numpy as np

data = {
    'name': ['김민수', '이지영', '박준호', '최서연', '정도윤'],
    'age': [25, 30, 28, 22, 35],
    'city': ['서울', '부산', '인천', '서울', '대전'],
    'score': [90, 85, 95, 80, np.nan]
}
df = pd.DataFrame(data)

# 데이터 측정
df.describe()

# 모든 데이터 타입 측정
df.describe(include='all')

# 수치형 데이터 측정
df.describe(include=[np.number])

# 범주형 데이터 측정
df.describe(include=['object'])

# 특정 열 분석
df['score'].describe()
# Out:
# count     4.000000
# mean     87.500000
# std       6.454972
# min      80.000000
# 25%      83.750000
# 50%      87.500000
# 75%      91.250000
# max      95.000000
# Name: score, dtype: float64

# %% [markdown]
# ### 6-2 DataFrame 열 선택 및 **조작**

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}
df = pd.DataFrame(data)

# 특정 열 선택
selected_col = df[['이름', '학과']]
selected_col
# DataFrame 열순서 변경
recorded_cols = df[['학과', '이름', '학년', '학점', '동아리']]
recorded_cols
# DataFrame 열이름 변경
df.rename = df.rename(columns={'이름':'학생명', '학점':'y', '동아리':'과외활동'})
df.rename
# Out:
#    학생명  학년    y     학과   과외활동
# 0  김철수   1  4.2  컴퓨터공학  프로그래밍
# 1  이영희   2  3.8    경영학   독서토론
# 2  박민수   3  4.5   전자공학   로봇공학
# 3  최지훈   4  3.9     의학   봉사활동
# 4  정소희   2  3.5    심리학   음악감상

# %% [markdown]
# ### 6-3 DataFrame 행 선택

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

#DataFrame 인덱스 지정
df = pd.DataFrame(data)
df = df.set_index('이름')
df

#DataFrame 행 선택
df.loc['김철수']
df.loc[['김철수', '이영희']]
df.loc['김철수':'박민수']

#DataFrame 위치 기반 행 선택
df.iloc[1]
df.iloc[[2,3]] #리스트로 만들어야 함
df.iloc[1:3] #슬라이싱도 가능함

#DataFrame 조건 기반 선택
df.loc[[True, False, True, False, False]]
print(df[['학점', '학년']], )
df.loc[df['학점'] >= 4.0]
df[df['학년'] == 2]
df[(df['학년'] == 2) & (df['학점'] >= 3.7)]
# Out:
#       학점  학년
# 이름
# 김철수  4.2   1
# 이영희  3.8   2
# 박민수  4.5   3
# 최지훈  3.9   4
# 정소희  3.5   2
#      학년   학점   학과   동아리
# 이름
# 이영희   2  3.8  경영학  독서토론

# %% [markdown]
# ### 6-4 DataFrame 정렬

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

#DataFrame 인덱스 지정
        #df = pd.DataFrame(data)
        #df = df.set_index('이름')
df = pd.DataFrame(data).set_index('이름')
df

#DataFrame 단일 열 오름차순, 내림차순 정렬
df.sort_values(by='학점')  #오름차순
df.sort_values(by='학점', ascending=False)

#DataFrame 복수 열 오름차순, 내림차순 정렬
df.sort_values(by=['학년','학점'], ascending=[True, False])

#DataFrame 인덱스 기분 오른차순, 내림차순 정렬
df.sort_index(ascending=False)
# Out:
#      학년   학점     학과    동아리
# 이름
# 최지훈   4  3.9     의학   봉사활동
# 정소희   2  3.5    심리학   음악감상
# 이영희   2  3.8    경영학   독서토론
# 박민수   3  4.5   전자공학   로봇공학
# 김철수   1  4.2  컴퓨터공학  프로그래밍

# %% [markdown]
# ## 6-5 실습 시나리오 - Kaggle을 활용한 데이터 수집 및 측정

# %% [markdown]
# - Kaggle([https://www.kaggle.com](https://www.kaggle.com)) 회원 가입
# - Kaggle 접근 토큰 생성(API 키)

# %% [markdown]
# ### Kaggle API 키 업로드

# %%
from google.colab import files
files.upload()

# %% [markdown]
# ### Kaggle API 키 사용을 위한 Colab 환경 설정

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ### Kaggle 데이터셋 다운로드

# %%
# !kaggle competitions download –c store-sales-time-series-forecasting

# !unzip store-sales-time-series-forecasting.zip

# %% [markdown]
# ### Kaggle 데이터셋 DataFrame 로드 및 살펴보기

# %%
import pandas as pd

# Grocery Sales 데이터 DataFrame 로드

# 판매 데이터 살펴보기

# %% [markdown]
# ### Kaggle 데이터셋 측정

# %%
# 판매 데이터 기본 통계량

# 매장 데이터 기본 정보

# 원유 가격 데이터 기본 정보
